# %% [markdown]
# <p1>To use MLP, CNN, RNN, RNN with LSTM</p1>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split 
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectPercentile, chi2
import tensorflow as tf

# %%
#Function to preprocess the data
def PreProc(X, Y):
    scaler = StandardScaler().fit(X)
    Columns_Scaled = scaler.transform(X)
    #pca = PCA(n_components = 1000).fit(Columns_Scaled).transform(Columns_Scaled)
    #Columns_Scaled = pca
    return Columns_Scaled

# %% [markdown]
# <h1>RNN with LSTM</h1>

# %%
df = pd.read_csv("emotions.csv")
#columns will be the features
columns = df.drop("label", axis = 1)
print(df.shape)
print(columns.shape)
#y will be the labels, which will be changed to 0,1,2 to represent the negative, neutral and positive state respectively
y = df.label
y = y.replace(["NEGATIVE", "NEUTRAL", "POSITIVE"], [0,1,2])
#Pre-processing columns
columns = PreProc(columns, y)
#splitting the data for training and testing purposes
X_Train, X_Test, Y_Train, Y_Test = train_test_split(columns, y, test_size = 0.2)
#converting to tensors
X = tf.constant(X_Train)
Y = tf.constant(Y_Train)
print(X.shape)
print(Y.shape)
#reshaping X tensor to fit the (batch_size, timestep, feature_length) format
X = tf.reshape(X, (X.shape[0], 1, X.shape[1]))
#adding a LSTM layer and a Dense Layer
model = tf.keras.Sequential()
model.add(tf.keras.layers.LSTM(units=5, input_shape=(1, X.shape[2])))
model.add(tf.keras.layers.Dense(units = 3, activation = 'softmax'))
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X, Y, epochs=100)
X_Test = tf.reshape(X_Test, (X_Test.shape[0], 1, X_Test.shape[1]))
y_pred = model.predict(X_Test)
check = []
for i in y_pred:
    check.append(np.where(i==max(i))[0][0])
print(classification_report(Y_Test, check))
# Out:
# (2132, 2549)
# (2132, 2548)
# (1705, 2548)
# (1705,)
# C:\Users\kaust\AppData\Local\Temp\ipykernel_25964\1888380280.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y = y.replace(["NEGATIVE", "NEUTRAL", "POSITIVE"], [0,1,2])
# C:\Users\kaust\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7797 - loss: 0.7257
# Epoch 2/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9324 - loss: 0.4261
# Epoch 3/100
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[41], line 2
#       1 X_Test = tf.constant(X_Test)
# ----> 2 X_Test = tf.reshape(X_Test, (X_Test.shape[0], 1, X_Test.shape[1]))
#       3 y_pred = model.predict(X_Test)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:88, in weak_tensor_unary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#      86 def wrapper(*args, **kwargs):
#      87   if not ops.is_auto_dtype_conversion_enabled():
# ---> 88     return op(*args, **kwargs)
#      89   bound_arguments = signature.bind(*args, **kwargs)
#      90   bound_arguments.apply_defaults()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
# ...

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.LSTM(units=5, input_shape=(1, 1000)))
#model.add(tf.keras.layers.Dense(units = 5, activation = 'softmax'))
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X, Y, epochs=100)

# %% [markdown]
# <h1>Conclusion</h1>
# <p1>Training accuracy according to study : 97.27%</p1>
# <br></br>
# <p1>Testing accuracy according to study : 87%</p1>
# <br></br>
# <p1>Training accuracy obtained : 99.61%</p1>
# <br></br>
# <p1>Testing accuracy obtained : 98%</p1>
# <br></br>
# <p1>N.B.: The model used here used both a LSTM layer and a Dense layer. When used without the dense layer, the accuracy reaches approx. 92%. It can be inferred that the addition of a Dense layer greatly increased the accuracy obtained</p1>

# %% [markdown]
# <h1>RNN</h1>

# %%
df = pd.read_csv("emotions.csv")
#columns will be the features
columns = df.drop("label", axis = 1)
print(df.shape)
print(columns.shape)
#y will be the labels, which will be changed to 0,1,2 to represent the negative, neutral and positive state respectively
y = df.label
y = y.replace(["NEGATIVE", "NEUTRAL", "POSITIVE"], [0,1,2])
#Pre-processing columns
columns = PreProc(columns, y)
#splitting the data for training and testing purposes
X_Train, X_Test, Y_Train, Y_Test = train_test_split(columns, y, test_size = 0.2)
#converting to tensors
X = tf.constant(X_Train)
Y = tf.constant(Y_Train)
print(X.shape)
print(Y.shape)
# Out:
# (2132, 2549)
# (2132, 2548)
# C:\Users\kaust\AppData\Local\Temp\ipykernel_18132\2852312980.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y = y.replace(["NEGATIVE", "NEUTRAL", "POSITIVE"], [0,1,2])
# (1705, 2548)
# (1705,)

# %%
#Reshaping the input value
X = tf.reshape(X, [X.shape[0], 1, X.shape[1]])
X_Test = tf.reshape(X_Test, [X_Test.shape[0], 1, X_Test.shape[1]])

# %%
#changing the dimensions of the X tensor to fit with the input requirements of the layer.
model = tf.keras.Sequential()
model.add(tf.keras.layers.SimpleRNN(3))
model.add(tf.keras.layers.Dense(units = 3, activation = 'softmax'))

# %%
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X, Y, epochs=100)
y_pred = model.predict(X_Test)
check = []
for i in y_pred:
    check.append(np.where(i==max(i))[0][0])
print(classification_report(Y_Test, check))
# Out:
# Epoch 1/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6663 - loss: 0.6569
# Epoch 2/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9107 - loss: 0.4711
# Epoch 3/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9270 - loss: 0.4457
# Epoch 4/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9460 - loss: 0.3991
# Epoch 5/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9390 - loss: 0.3880
# Epoch 6/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9418 - loss: 0.3631
# Epoch 7/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9454 - loss: 0.3421
# Epoch 8/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9466 - loss: 0.3189
# Epoch 9/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9519 - loss: 0.2915
# Epoch 10/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9457 - loss: 0.2819
# Epoch 11/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9542 - loss: 0.2500
# Epoch 12/100
# ...

# %%
model.summary()
# Out:
# Model: "sequential_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn_4 (SimpleRNN)             │ (None, 3)                   │           7,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 3)                   │              12 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,338 (59.92 KB)
#  Trainable params: 7,668 (29.95 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 7,670 (29.96 KB)

# %% [markdown]
# <h1>CNN</h1>

# %%
df = pd.read_csv("emotions.csv")
#columns will be the features
columns = df.drop("label", axis = 1)
print(df.shape)
print(columns.shape)
#y will be the labels, which will be changed to 0,1,2 to represent the negative, neutral and positive state respectively
y = df.label
y = y.replace(["NEGATIVE", "NEUTRAL", "POSITIVE"], [0,1,2])
#Pre-processing columns
columns = PreProc(columns, y)
#splitting the data for training and testing purposes
X_Train, X_Test, Y_Train, Y_Test = train_test_split(columns, y, test_size = 0.2)
#converting to tensors
X = tf.constant(X_Train)
Y = tf.constant(Y_Train)
print(X.shape)
print(Y.shape)
#reshaping X tensor to fit the (batch_size, timestep, feature_length) format
X = tf.reshape(X, (X.shape[0], 1, X.shape[1]))
#adding a LSTM layer and a Dense Layer
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv1D(33,44, activation = 'relu'))
model.add(tf.keras.layers.Dense(units = 3, activation = 'softmax'))
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X, Y, epochs=100)
X_Test = tf.reshape(X_Test, (X_Test.shape[0], 1, X_Test.shape[1]))
y_pred = model.predict(X_Test)
check = []
for i in y_pred:
    check.append(np.where(i==max(i))[0][0])
print(classification_report(Y_Test, check))
# Out:
# (2132, 2549)
# (2132, 2548)
# C:\Users\kaust\AppData\Local\Temp\ipykernel_18132\3832470520.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y = y.replace(["NEGATIVE", "NEUTRAL", "POSITIVE"], [0,1,2])
# (1705, 2548)
# (1705,)
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 25
#      23 model.add(tf.keras.layers.Dense(units = 3, activation = 'softmax'))
#      24 model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# ---> 25 model.fit(X, Y, epochs=100)
#      26 X_Test = tf.reshape(X_Test, (X_Test.shape[0], 1, X_Test.shape[1]))
#      27 y_pred = model.predict(X_Test)
#
# ...

# %% [markdown]
# <h1>MLP</h1>

# %%
df = pd.read_csv("emotions.csv")
#columns will be the features
columns = df.drop("label", axis = 1)
print(df.shape)
print(columns.shape)
#y will be the labels, which will be changed to 0,1,2 to represent the negative, neutral and positive state respectively
y = df.label
y = y.replace(["NEGATIVE", "NEUTRAL", "POSITIVE"], [0,1,2])
#Pre-processing columns
columns = PreProc(columns, y)
#splitting the data for training and testing purposes
X_Train, X_Test, Y_Train, Y_Test = train_test_split(columns, y, test_size = 0.2)
#converting to tensors
X = tf.constant(X_Train)
Y = tf.constant(Y_Train)
print(X.shape)
print(Y.shape)
#reshaping X tensor to fit the (batch_size, timestep, feature_length) format
X = tf.reshape(X, (X.shape[0], 1, X.shape[1]))
#adding a LSTM layer and a Dense Layer
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv1D(33,44, activation = 'relu'))
model.add(tf.keras.layers.Dense(units = 3, activation = 'softmax'))
model.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X, Y, epochs=100)
X_Test = tf.reshape(X_Test, (X_Test.shape[0], 1, X_Test.shape[1]))
y_pred = model.predict(X_Test)
check = []
for i in y_pred:
    check.append(np.where(i==max(i))[0][0])
print(classification_report(Y_Test, check))
